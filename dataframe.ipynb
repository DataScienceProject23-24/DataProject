# %%
import pandas as pd
df_CulturalHeritageObject = pd.read_csv("C:\\Users\\vdant\\Documents\\DIGITAL HUMANITIES BOLOGONA\\PERONI\\DATA SCIENCE\\DS_Project\\meta.csv",
                            keep_default_na=False,
                            dtype={
                               "Id": "string",
                               "Type": "string",
                               "Title": "string",
                               "Date":"string",
                               "Author": "string",
                               "Owner": "string",
                               "Place": "string",
                            })
df_Person = pd.DataFrame({
    "name" : df_CulturalHeritageObject["Author"]
})
df_Person
# Out:
#                                            name
# 0          Benincasa, Grazioso (ULAN:500114874)
# 1                    Teofrasto (VIAF:265397758)
# 2          Dioscorides Pedanius (VIAF:78822798)
# 3      Plinius Secundus, Gaius (VIAF:100219162)
# 4             Agnese, Battista (ULAN:500048088)
# 5    Ramusio, Giovanni Battista (VIAF:68943129)
# 6   Anghiera, Pietro Martire d' (VIAF:68967770)
# 7                Acosta, José de (VIAF:2465365)
# 8            Monardes, Nicolás (VIAF:100203985)
# 9
# 10
# 11
# 12          Carracci, Agostino (ULAN:500115349)
# 13         Dioscorides Pedanius (VIAF:78822798)
# 14
# 15              Monti, Giuseppe (VIAF:54929912)
# 16          Aldrovandi, Ulisse (VIAF:100190422)
# 17          Aldrovandi, Ulisse (VIAF:100190422)
# 18          Aldrovandi, Ulisse (VIAF:100190422)
# 19          Aldrovandi, Ulisse (VIAF:100190422)
# 20          Aldrovandi, Ulisse (VIAF:100190422)
# 21          Aldrovandi, Ulisse (VIAF:100190422)
# ...

# %%
del df_CulturalHeritageObject["Author"]
df_CulturalHeritageObject
# Out:
#     Id               Type                                              Title  \
# 0    1     Nautical chart                                     Nautical chart
# 1    2     Printed volume                              The History of Plants
# 2    3          Herbarium                                On Medical Material
# 3    4     Printed volume                                The Natural History
# 4    5     Nautical chart   Incomplete coastal profile of the American co...
# 5    6     Nautical chart                                       Map of Cusco
# 6    7     Printed volume                                   On the New World
# 7    8     Printed volume            Natural and Moral History of the Indies
# 8    9   Printed material                                            Tobacco
# 9   10           Specimen                            Jaguar (Linnaeus, 1758)
# 10  11           Specimen           Atlantic horseshoe crab (Linnaeus, 1758)
# ...
