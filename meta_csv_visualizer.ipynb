# %%
from pandas import read_csv, Series

CulturalHeritageObject = read_csv("resources\meta.csv", keep_default_na=False, 
                  dtype={
                      "Id" : "string",
                      "Title" : "string",
                      "Date" : "string",
                      "Author" : "string",
                      "Owner" : "string",
                      "Place" : "string",
                      "Type" : "string"
                })

CulturalHeritageObject
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\annap\AppData\Local\Temp\ipykernel_20616\3752603739.py:3: SyntaxWarning: invalid escape sequence '\m'
#   CulturalHeritageObject = read_csv("resources\meta.csv", keep_default_na=False,
#     Id               Type                                              Title  \
# 0    1     Nautical chart                                     Nautical chart
# 1    2     Printed volume                              The History of Plants
# 2    3          Herbarium                                On Medical Material
# 3    4     Printed volume                                The Natural History
# 4    5     Nautical chart   Incomplete coastal profile of the American co...
# 5    6     Nautical chart                                       Map of Cusco
# 6    7     Printed volume                                   On the New World
# ...
